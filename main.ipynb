# %%
from datasets import load_dataset

# Load all 3 subsets
nlp = load_dataset("EleutherAI/sycophancy", "sycophancy_on_nlp_survey")
phil = load_dataset("EleutherAI/sycophancy", "sycophancy_on_philpapers2020")
politics = load_dataset("EleutherAI/sycophancy", "sycophancy_on_political_typology_quiz")
